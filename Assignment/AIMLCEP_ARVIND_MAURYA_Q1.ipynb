# %% [markdown]
# <a href="https://colab.research.google.com/github/arvind-maurya/MachineLearning/blob/master/Assignment/AIMLCEP_ARVIND_MAURYA_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ${\text{(a) [C] Find optimal } \beta \text{ by setting λ = 0. Let the optimal β be called } \beta_0^* }$

# %% [markdown]
# **Linear Regression using OLSR**

# %% [markdown]
# ### Pre-processing the data set

# %%
#First, we import the required packages
import pandas as pd #the pandas library is useful for data processing 
import matplotlib.pyplot as plt #the matplotlib library is useful for plotting purposes

# The following python directive helps to plot the graph in the notebook directly
# %matplotlib inline

# %% [markdown]
# Now lets load the Q1_train dataset using Pandas

# %%
#Let us explore the data and the description 
weight_height_data = pd.read_excel('https://github.com/arvind-maurya/MachineLearning/blob/master/Assignment/Q1/Q1_train.xlsx?raw=true', index_col=False, header=0)
#print the first few rows of the data 
weight_height_data.head()
# Out:
#    Species  Length_cm  Height_pct  Width_pct  Weight_g
# 0        1       30.0        38.4       13.4     242.0
# 1        1       31.2        40.0       13.8     290.0
# 2        1       31.1        39.8       15.1     340.0
# 3        1       33.5        38.0       13.3     363.0
# 4        1       34.0        36.6       15.1     430.0

# %%
print('Shape of dataset= ', weight_height_data.shape) # To get no of rows and columns

#Lets print some of the important info about the data set and its attributes
weight_height_data.info()
# Out:
# Shape of dataset=  (124, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Species     124 non-null    int64
#  1   Length_cm   124 non-null    float64
#  2   Height_pct  124 non-null    float64
#  3   Width_pct   124 non-null    float64
#  4   Weight_g    124 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 5.0 KB

# %%
#Lets check if any of the attribute has null value. If null value are there then we need to do some preprocessing of the data.
# isna() will return 'True' is value is 'None' or 'numpy.NaN'
weight_height_data.isna().sum()
# Out:
# Species       0
# Length_cm     0
# Height_pct    0
# Width_pct     0
# Weight_g      0
# dtype: int64

# %% [markdown]
# We dont see any attributes has null value from above result.

# %%
#Lets see some correlation betwen the attributes
weight_height_data.corr()
# Out:
#              Species  Length_cm  Height_pct  Width_pct  Weight_g
# Species     1.000000  -0.139894   -0.667973   0.078128 -0.147799
# Length_cm  -0.139894   1.000000    0.135548   0.030504  0.921418
# Height_pct -0.667973   0.135548    1.000000   0.454868  0.214705
# Width_pct   0.078128   0.030504    0.454868   1.000000  0.141040
# Weight_g   -0.147799   0.921418    0.214705   0.141040  1.000000

# %% [markdown]
# Seeing the data as mere numbers might not be interesting. So, let us use some graphical ways to visualize the data.

# %%
#We will plot multiple scatter plots of weight_g vs other attributes
fig = plt.figure(figsize=(10, 10)) 

fig.constrained_layout=True

ax11 = fig.add_subplot(421)
ax12 = fig.add_subplot(422)
ax21 = fig.add_subplot(423)
ax22 = fig.add_subplot(424)


ax11.scatter(weight_height_data['Species'],weight_height_data['Weight_g'])
ax11.set_xlabel('Species')
ax11.set_ylabel('Weight_g')


ax12.scatter(weight_height_data['Length_cm'],weight_height_data['Weight_g'])
ax12.set_xlabel('Length_cm')
ax12.set_ylabel('Weight_g')

ax21.scatter(weight_height_data['Height_pct'],weight_height_data['Weight_g'])
ax21.set_xlabel('Height_pct')
ax21.set_ylabel('Weight_g')

ax22.scatter(weight_height_data['Width_pct'],weight_height_data['Weight_g'])
ax22.set_xlabel('Width_pct')
ax22.set_ylabel('Weight_g')


plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# We see some mixed trend in most of the plots.

# %% [markdown]
# ###$\text {   i. [C, R] Report the value of } \beta_0^* \text {and the RMSE and } R^2 \text { values for train data set.}$

# %%
#Let us now compute beta_train 
n_train = len(weight_height_data.index) #number of data points in the data set
print('number of data points in the data set:',n_train)
# Out:
# number of data points in the data set: 124

# %%
#extract the predictor variable columns 
cols = [0,1,2,3]
X_data = weight_height_data[weight_height_data.columns[cols]]

X_data
# Out:
#      Species  Length_cm  Height_pct  Width_pct
# 0          1       30.0        38.4       13.4
# 1          1       31.2        40.0       13.8
# 2          1       31.1        39.8       15.1
# 3          1       33.5        38.0       13.3
# 4          1       34.0        36.6       15.1
# ..       ...        ...         ...        ...
# 119        7       42.5        26.2       15.6
# 120        7       44.6        28.7       15.4
# 121        7       45.2        26.4       16.1
# 122        7       45.5        27.5       16.3
# 123        7       46.6        26.8       16.3
#
# [124 rows x 4 columns]

# %%
#convert predictor variable columns into a numpy array

X_array = weight_height_data[weight_height_data.columns[cols]].to_numpy()
#Lets see the first few record
X_array[0:4]
# Out:
# array([[ 1. , 30. , 38.4, 13.4],
#        [ 1. , 31.2, 40. , 13.8],
#        [ 1. , 31.1, 39.8, 15.1],
#        [ 1. , 33.5, 38. , 13.3]])

# %%
import numpy as np
#add a column of ones to X_array
X_train = np.hstack((X_array, np.ones((X_array.shape[0], 1), dtype=X_array.dtype)))
#Lets see the first few record
X_train[0:4]
# Out:
# array([[ 1. , 30. , 38.4, 13.4,  1. ],
#        [ 1. , 31.2, 40. , 13.8,  1. ],
#        [ 1. , 31.1, 39.8, 15.1,  1. ],
#        [ 1. , 33.5, 38. , 13.3,  1. ]])

# %%
#convert response variable columns into a numpy array

response_cols = [4]
y_train = weight_height_data[weight_height_data.columns[response_cols]].to_numpy()
y_train.shape
# Out:
# (124, 1)

# %%
#Now we are ready for finding beta
#print('X shape:',X.shape,'y shape:',y.shape)

XTX = np.matmul(np.transpose(X_train),X_train)
print('XTX shape:',XTX.shape)

Xy = np.matmul(np.transpose(X_train),y_train)
#print('Xy shape:',Xy.shape)

rank = np.linalg.matrix_rank(XTX)
print('Rank of XTX:', rank)

if rank == XTX.shape[0]:
  print('XTX is of full rank. Hence data is linearly independent.')
  print('\n')

beta_train = np.matmul(np.linalg.inv(XTX),Xy)

print('Beta train:\n',beta_train)
# Out:
# XTX shape: (5, 5)
# Rank of XTX: 5
# XTX is of full rank. Hence data is linearly independent.
#
#
# Beta train:
#  [[   2.4173551 ]
#  [  27.8581628 ]
#  [   2.67475542]
#  [  13.06363395]
#  [-740.77633006]]

# %% [markdown]
# Lets plot the Residual Plot
#
# Sometimes it would be useful to plot the error (or) $\textbf{residual}$ $e^i$ versus the fitted values $\hat{y}^i=\beta_0 + \sum_{j=1}^{d} \beta_j x^i_j$.

# %%
e_i_residuals_list = [] 
for i in range(n_train): 
  x_i = X_train[i,:] #access i-th row of X
  y_i = y_train[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta_train) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(weight_height_data['Weight_g'], e_i_residuals_list,color='r')
plt.title("Residual plot")
plt.xlabel("Weight_g")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %% [markdown]
# Let us compute $R^2$.

# %% [markdown]
# $\textbf{Coefficient of multiple determination}$ and is denoted by $R^2$.
#
# It is known that $0\leq R^2 \leq 1$.

# %%
#We shall now compute R^2 for training height weight data
n_train = len(weight_height_data.index) #number of data points in the training data set
#first we shall compute y_bar 
y_bar_train = 0
for i in range(n_train): #access each row from the training data set 
  y_train_i = float(weight_height_data.iat[i,4]) #access element at weight_g column
  y_bar_train += y_train_i

y_bar_train /= n_train
print('y_bar_train :',y_bar_train)

#Next we shall compute sigma_yy, which is the variance of y_train
sigma_yy_train = 0
for i in range(n_train): #access each row from the training data set 
  y_i = float(weight_height_data.iat[i,4]) #access element at weight_g column
  sigma_yy_train += (y_i-y_bar_train)**2

print('sigma_yy_train :', sigma_yy_train)

#now we can compute sum of squared residuals 
sum_sq_residuals_train = 0
for i in range(n_train): #access each row from the training data set 
  x_i = X_train[i,:] #access i-th row of X_train
  y_i = y_train[i] #access i-th row of y_train

  y_pred_i = np.dot(x_i,beta_train) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals_train += (e_i)**2

RMSE = np.sqrt(sum_sq_residuals_train/n_train)

print('sum of squared residuals :', sum_sq_residuals_train)
print('Root Mean Squared Error (RMSE) :', RMSE)

#Then we will compute the R^2 quantity
R_sq_train = 1-sum_sq_residuals_train/sigma_yy_train
print('R^2 score:',R_sq_train)
# Out:
# y_bar_train : 404.4782258064517
# sigma_yy_train : 15451937.951209672
# sum of squared residuals : [2104316.3107336]
# Root Mean Squared Error (RMSE) : [130.27007649]
# R^2 score: [0.86381538]

# %% [markdown]
# $\Large{\text{Finding $\beta$ using sklearn library}}$

# %%
from sklearn.linear_model import LinearRegression
# creating an object of LinearRegression class
LR = LinearRegression()
# fitting the training data
LR.fit(X_train,y_train)
#print the coefficients and the intercept
print('intercept: ', LR.intercept_)
print('coefficients:')
print(LR.coef_)

print('Recall the coefficients and intercept from our formula:')
print(beta_train)
# Out:
# intercept:  [-740.77633006]
# coefficients:
# [[ 2.4173551  27.8581628   2.67475542 13.06363395  0.        ]]
# Recall the coefficients and intercept from our formula:
# [[   2.4173551 ]
#  [  27.8581628 ]
#  [   2.67475542]
#  [  13.06363395]
#  [-740.77633006]]

# %% [markdown]
# If you see the beta calculated from sklearn and from code is same.

# %%
y_train_prediction = LR.predict(X_train)
#lets see first few record
y_train_prediction[0:5]
# Out:
# array([[375.14921228],
#        [418.0840699 ],
#        [431.74602667],
#        [470.27651653],
#        [503.97548146]])

# %%
# importing R2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# computing R2 score and sum of square residuals
score=r2_score(y_train,y_train_prediction)
print('From scikit learn:')
print('R2 score is:',score)
mse=mean_squared_error(y_train,y_train_prediction)
print('sum of squared residuals:',n_train*mse)
print('RMSE:',np.sqrt(mse))
print('*****************')

print('Recall the R2 score, sum of squared resuiduals and rmse from our formula: ')
print('R^2 Score:',R_sq_train)
print('sum of squared residuals:',sum_sq_residuals_train)
print('RMSE:',np.sqrt(sum_sq_residuals_train/n_train))
# Out:
# From scikit learn:
# R2 score is: 0.8638153791855696
# sum of squared residuals: 2104316.310733597
# RMSE: 130.2700764891798
# *****************
# Recall the R2 score, sum of squared resuiduals and rmse from our formula:
# R^2 Score: [0.86381538]
# sum of squared residuals: [2104316.3107336]
# RMSE: [130.27007649]

# %% [markdown]
# If you see the RMSE and R^2 calculated from Sklearn and code is same.

# %% [markdown]
# ### **===================================================================**

# %% [markdown]
# ###$\text{ii. [R, C] Justify with appropriate reasons if the response variable Weight_g in the training data set given in Q1 train.xlsx file can (or) cannot be modeled using a linear regression model identified by} \beta_0^* \text {. Using } \beta_0^* \text { , predict the Weight_g value for the test data set in Q1 test.xlsx file and report the predictions.}$

# %% [markdown]
# ${\text{First, let us prepare the test data as numpy arrays}}$

# %%
weight_height_data_test = pd.read_excel('https://github.com/arvind-maurya/MachineLearning/blob/master/Assignment/Q1/Q1_test.xlsx?raw=true', index_col=False, header=0)
weight_height_data_test.head()
# Out:
#    Species  Length_cm  Height_pct  Width_pct  Weight_g
# 0        1       34.7        39.2       14.2       NaN
# 1        1       39.5        38.3       14.1       NaN
# 2        1       46.5        37.9       13.7       NaN
# 3        1       41.5        39.8       14.1       NaN
# 4        1       35.1        39.9       13.8       NaN

# %%
#extract the predictor variable columns for test data
cols = [0,1,2,3]
# print (airline_costs_data.columns[cols])
X_test_data = weight_height_data_test[weight_height_data_test.columns[cols]]

X_test_data.head()
# Out:
#    Species  Length_cm  Height_pct  Width_pct
# 0        1       34.7        39.2       14.2
# 1        1       39.5        38.3       14.1
# 2        1       46.5        37.9       13.7
# 3        1       41.5        39.8       14.1
# 4        1       35.1        39.9       13.8

# %%
#convert predictor variable columns into a numpy array

X_test_array = weight_height_data_test[weight_height_data_test.columns[cols]].to_numpy()
X_test_array
# Out:
# array([[ 1. , 34.7, 39.2, 14.2],
#        [ 1. , 39.5, 38.3, 14.1],
#        [ 1. , 46.5, 37.9, 13.7],
#        [ 1. , 41.5, 39.8, 14.1],
#        [ 1. , 35.1, 39.9, 13.8],
#        [ 2. , 34. , 31.6, 19.3],
#        [ 3. , 24.3, 27.3, 14.6],
#        [ 3. , 29.2, 30.4, 15.4],
#        [ 3. , 27.2, 27.7, 14.1],
#        [ 3. , 21.2, 26.3, 13.7],
#        [ 4. , 23.2, 40.5, 14.7],
#        [ 4. , 19.8, 37.4, 13.5],
#        [ 5. , 12.6, 15.7, 10.2],
#        [ 5. , 13.1, 16.9,  9.8],
#        [ 5. , 13.1, 16.9,  8.9],
#        [ 6. , 64. , 15. ,  9.6],
#        [ 6. , 45.5, 16. ,  9.5],
#        [ 6. , 45.8, 17. , 11.2],
#        [ 7. , 42.4, 29.2, 17.6],
#        [ 7. , 31.6, 24.1, 15.1],
#        [ 7. , 19.4, 26.8, 16.1],
#        [ 7. , 22.5, 25.3, 16.3],
#        [ 7. , 22.8, 28. , 15.5],
#        [ 7. , 25. , 25.1, 14.9],
#        [ 7. , 24.2, 24.6, 15. ],
#        [ 7. , 24.5, 21.3, 14.8],
#        [ 7. , 29.4, 26.6, 14.3],
#        [ 7. , 46. , 27.4, 17.7],
# ...

# %%
#add a column of ones to X_train_array
X_test = np.hstack((X_test_array, np.ones((X_test_array.shape[0], 1), dtype=X_test_array.dtype)))

X_test
# Out:
# array([[ 1. , 34.7, 39.2, 14.2,  1. ],
#        [ 1. , 39.5, 38.3, 14.1,  1. ],
#        [ 1. , 46.5, 37.9, 13.7,  1. ],
#        [ 1. , 41.5, 39.8, 14.1,  1. ],
#        [ 1. , 35.1, 39.9, 13.8,  1. ],
#        [ 2. , 34. , 31.6, 19.3,  1. ],
#        [ 3. , 24.3, 27.3, 14.6,  1. ],
#        [ 3. , 29.2, 30.4, 15.4,  1. ],
#        [ 3. , 27.2, 27.7, 14.1,  1. ],
#        [ 3. , 21.2, 26.3, 13.7,  1. ],
#        [ 4. , 23.2, 40.5, 14.7,  1. ],
#        [ 4. , 19.8, 37.4, 13.5,  1. ],
#        [ 5. , 12.6, 15.7, 10.2,  1. ],
#        [ 5. , 13.1, 16.9,  9.8,  1. ],
#        [ 5. , 13.1, 16.9,  8.9,  1. ],
#        [ 6. , 64. , 15. ,  9.6,  1. ],
#        [ 6. , 45.5, 16. ,  9.5,  1. ],
#        [ 6. , 45.8, 17. , 11.2,  1. ],
#        [ 7. , 42.4, 29.2, 17.6,  1. ],
#        [ 7. , 31.6, 24.1, 15.1,  1. ],
#        [ 7. , 19.4, 26.8, 16.1,  1. ],
#        [ 7. , 22.5, 25.3, 16.3,  1. ],
#        [ 7. , 22.8, 28. , 15.5,  1. ],
#        [ 7. , 25. , 25.1, 14.9,  1. ],
# ...

# %% [markdown]
# ${\text{Compute predictions on test data using } \beta_0^*}$

# %%
## Predict based on scikit learn

y_test_prediction =  LR.predict(X_test)

y_test_prediction
# Out:
# array([[ 518.67328896],
#        [ 648.67882715],
#        [ 837.39061103],
#        [ 708.40728589],
#        [ 526.46342929],
#        [ 547.88632204],
#        [ 207.17897006],
#        [ 362.42661677],
#        [ 282.50572739],
#        [ 106.38663939],
#        [ 215.56548102],
#        [  96.87962494],
#        [-202.43397682],
#        [-190.5206425 ],
#        [-202.27791305],
#        [1222.18243728],
#        [ 708.17481742],
#        [ 741.4151994 ],
#        [ 765.35407437],
#        [ 418.18557856],
#        [  98.60146593],
#        [ 183.56236428],
#        [ 188.6907456 ],
#        [ 234.38373268],
#        [ 212.06618812],
#        [ 208.98421728],
#        [ 353.13360178],
#        [ 862.13526411],
#        [ 383.2596555 ],
#        [ 189.77831477],
#        [ 749.44259551],
#        [ 756.02210161],
#        [ -15.63034889]])

# %%
n_test = len(weight_height_data_test.index)
n_test
# Out:
# 33

# %%
## we first compute size of test data
n_test = len(weight_height_data_test.index) #number of data points in the test data
# print('number of data points in the test data:',n_test)

e_i_residuals_list_test = [] ## stores residuals on test data
for i in range(n_test):
  
  x_i = X_test[i,:] #access i-th row of X_test

  y_pred_i = np.dot(x_i,beta_train) # compute the prediction obtained using the regression coefficients 
  #e_i_test = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i
  
  print(y_pred_i)
# Out:
# [518.67328896]
# [648.67882715]
# [837.39061103]
# [708.40728589]
# [526.46342929]
# [547.88632204]
# [207.17897006]
# [362.42661677]
# [282.50572739]
# [106.38663939]
# [215.56548102]
# [96.87962494]
# [-202.43397682]
# [-190.5206425]
# [-202.27791305]
# [1222.18243728]
# [708.17481742]
# [741.4151994]
# [765.35407437]
# [418.18557856]
# [98.60146593]
# [183.56236428]
# [188.6907456]
# [234.38373268]
# [212.06618812]
# [208.98421728]
# [353.13360178]
# [862.13526411]
# [383.2596555]
# [189.77831477]
# [749.44259551]
# [756.02210161]
# [-15.63034889]

# %%
weight_height_data_test.insert(5,'weight_predict',y_test_prediction)
weight_height_data_test.head()
# Out:
#    Species  Length_cm  Height_pct  Width_pct  Weight_g  weight_predict
# 0        1       34.7        39.2       14.2       NaN      518.673289
# 1        1       39.5        38.3       14.1       NaN      648.678827
# 2        1       46.5        37.9       13.7       NaN      837.390611
# 3        1       41.5        39.8       14.1       NaN      708.407286
# 4        1       35.1        39.9       13.8       NaN      526.463429

# %%
#We shall now compute R^2 for training weight height data

#first we shall compute y_bar 
y_bar_test = 0
for i in range(n_test): #access each row from the test data set 
  y_test_i = float(weight_height_data_test.iat[i,5]) #access element at weight_g column
  # y_test_i = y_test_prediction[i]
  y_bar_test += y_test_i

y_bar_test /= n_test
print('y_bar_test',y_bar_test)

#Next we shall compute sigma_yy, which is the variance of y_test
sigma_yy_test = 0
for i in range(n_test): #access each row from the training data set 
  y_i = float(weight_height_data_test.iat[i,5]) #access element at weight_g column
  # y_i = y_pred_i
  sigma_yy_test += (y_i-y_bar_test)**2

print('sigma_yy_test:', sigma_yy_test)

#now we can compute sum of squared residuals 
sum_sq_residuals_test = 0
for i in range(n_test): #access each row from the training data set 
  x_i = X_test[i,:] #access i-th row of X_test
  y_i = y_test_prediction[i] #access i-th row of y_test

  y_pred_i = np.dot(x_i,beta_train) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_test_prediction[i] #compute the difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals_test += (e_i)**2

print('sum of squared residuals:', sum_sq_residuals_test)
rmse = np.sqrt(sum_sq_residuals_test/n_test)
print('Root Mean Squarred Error for test (RMSE):', rmse)

#Then we will compute the R^2 quantity
R_sq_test = 1 - sum_sq_residuals_test/sigma_yy_test
print('R^2 score for test:',R_sq_test)
# Out:
# y_bar_test 385.5440089955785
# sigma_yy_test: 3716957.220159445
# sum of squared residuals: [0.]
# Root Mean Squarred Error for test (RMSE): [0.]
# R^2 score for test: [1.]

# %% [markdown]
# ### **================================================================**

# %% [markdown]
# ###$\text {iii. [C, R] From the components of }\beta_0^* \text {, can you compare the relative significance of the predictor variables and identify two most significant attributes? Using only the two most signicant attributes, solve
# the OLSR problem and report the RMSE and } R^2 \text { values for train data set. Explain using your results if the less significant attributes can be removed from the data set altogether.}$

# %%
#First, we import the required packages
import pandas as pd #the pandas library is useful for data processing 
import matplotlib.pyplot as plt #the matplotlib library is useful for plotting purposes

# The following python directive helps to plot the graph in the notebook directly
# %matplotlib inline
import seaborn as sns

# %%
#Let us explore the data and the description 
weight_height_data_Q1_3 = pd.read_excel('https://github.com/arvind-maurya/MachineLearning/blob/master/Assignment/Q1/Q1_train.xlsx?raw=true', index_col=False, header=0)
#print the first few rows of the data 
weight_height_data_Q1_3.head()
# Out:
#    Species  Length_cm  Height_pct  Width_pct  Weight_g
# 0        1       30.0        38.4       13.4     242.0
# 1        1       31.2        40.0       13.8     290.0
# 2        1       31.1        39.8       15.1     340.0
# 3        1       33.5        38.0       13.3     363.0
# 4        1       34.0        36.6       15.1     430.0

# %%
print('Shape of dataset= ', weight_height_data_Q1_3.shape) # To get no of rows and columns
#if you wish to print the entire data, then use the following
weight_height_data_Q1_3.info()
# Out:
# Shape of dataset=  (124, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Species     124 non-null    int64
#  1   Length_cm   124 non-null    float64
#  2   Height_pct  124 non-null    float64
#  3   Width_pct   124 non-null    float64
#  4   Weight_g    124 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 5.0 KB

# %%
sp = weight_height_data_Q1_3['Species'].value_counts()
sp = pd.DataFrame(sp)
sp.T
# Out:
#           7   1   3   6   5  4  2
# Species  41  29  15  14  11  9  5

# %%
sns.barplot(x= sp.index, y = sp.Species) # df_sp.index will returns row labels of dataframe
plt.xlabel('Species')
plt.ylabel('Count of Species')
plt.rcParams["figure.figsize"] = (10,6)
plt.title('Fish Count Based On Species')
plt.show()

# %%
#Now lets the training data where weight_g is 0 or negative
weight_height_data_Q1_3[weight_height_data_Q1_3.Weight_g <= 0]
# Out:
# Empty DataFrame
# Columns: [Species, Length_cm, Height_pct, Width_pct, Weight_g]
# Index: []

# %% [markdown]
# Correlation Check:
#
# Correlation helps us investigate and establish relationships between variables
# Note that high amount of correlation between independent variables suggest that linear regression estimation will be unreliable

# %%
weight_height_data_Q1_3.corr()
# Out:
#              Species  Length_cm  Height_pct  Width_pct  Weight_g
# Species     1.000000  -0.139894   -0.667973   0.078128 -0.147799
# Length_cm  -0.139894   1.000000    0.135548   0.030504  0.921418
# Height_pct -0.667973   0.135548    1.000000   0.454868  0.214705
# Width_pct   0.078128   0.030504    0.454868   1.000000  0.141040
# Weight_g   -0.147799   0.921418    0.214705   0.141040  1.000000

# %%
plt.rcParams["figure.figsize"] = (10,6) # Custom figure size in inches
sns.heatmap(weight_height_data_Q1_3.corr(), annot =True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#Let us now compute beta_train 
n_train_Q1_3 = len(weight_height_data_Q1_3.index) #number of data points in the data set
print('number of data points in the data set:',n_train_Q1_3)
# Out:
# number of data points in the data set: 124

# %% [markdown]
# **Looking at the beta value and correlation matrix, i see that the most significant attributes is length and width**

# %%
#extract the predictor variable columns. We see that Length and width is the most significant attributes
cols = [1,3]
X_data_Q1_3 = weight_height_data_Q1_3[weight_height_data_Q1_3.columns[cols]]

X_data_Q1_3.head()
# Out:
#    Length_cm  Width_pct
# 0       30.0       13.4
# 1       31.2       13.8
# 2       31.1       15.1
# 3       33.5       13.3
# 4       34.0       15.1

# %%
#convert predictor variable columns into a numpy array

X_array_Q1_3 = weight_height_data_Q1_3[weight_height_data_Q1_3.columns[cols]].to_numpy()
#X_array

# %%
import numpy as np
#add a column of ones to X_array
X_train_Q1_3 = np.hstack((X_array_Q1_3, np.ones((X_array_Q1_3.shape[0], 1), dtype=X_array_Q1_3.dtype)))

#X_train_Q1_3

# %%
#convert predictor variable columns into a numpy array
response_cols = [4]
y_train_Q1_3 = weight_height_data_Q1_3[weight_height_data_Q1_3.columns[response_cols]].to_numpy()
#y_train_Q1_3

# %%
#Now we are ready for finding beta
#print('X shape:',X.shape,'y shape:',y.shape)

XTX = np.matmul(np.transpose(X_train_Q1_3),X_train_Q1_3)
print('XTX shape:',XTX.shape)

Xy = np.matmul(np.transpose(X_train_Q1_3),y_train_Q1_3)
#print('Xy shape:',Xy.shape)

#Solving via matrix multiplication
beta_train_Q1_3 = np.matmul(np.linalg.inv(XTX),Xy)

#Solving via linalg solve routine
beta_train_linalg = np.linalg.solve(XTX,Xy)

#Solving via scipy lib
import scipy.linalg
beta_train_scipy = scipy.linalg.solve(XTX,Xy)


print('Beta from matrix multiplication:\n',beta_train_Q1_3)
print('Beta from numpy linalg:\n',beta_train_linalg)
print('Beta from scipy linalg:\n',beta_train_scipy)
# Out:
# XTX shape: (3, 3)
# Beta from matrix multiplication:
#  [[  28.02625976]
#  [  17.87051592]
#  [-726.86845722]]
# Beta from numpy linalg:
#  [[  28.02625976]
#  [  17.87051592]
#  [-726.86845722]]
# Beta from scipy linalg:
#  [[  28.02625976]
#  [  17.87051592]
#  [-726.86845722]]

# %% [markdown]
# ${\text{Residual Plot}}$
#
# Sometimes it would be useful to plot the error (or) $\textbf{residual}$ $e^i$ versus the fitted values $\hat{y}^i=\beta_0 + \sum_{j=1}^{d} \beta_j x^i_j$.

# %%
e_i_residuals_list = [] 
for i in range(n_train_Q1_3): 
  x_i = X_train_Q1_3[i,:] #access i-th row of X
  y_i = y_train_Q1_3[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta_train_Q1_3) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(weight_height_data_Q1_3['Weight_g'], e_i_residuals_list,color='r')
plt.title("Residual plot")
plt.xlabel("Weight_g")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %% [markdown]
# Note that the residual plot helps to check the variance in the errors $e^i$.

# %% [markdown]
# Let us compute $R^2$.

# %%
#We shall now compute R^2 for training height weight data
n_train_Q1_3 = len(weight_height_data_Q1_3.index) #number of data points in the training data set
#first we shall compute y_bar 
y_bar_train = 0
for i in range(n_train_Q1_3): #access each row from the training data set 
  y_train_Q1_3_i = float(weight_height_data_Q1_3.iat[i,4]) #access element at weight_g column
  y_bar_train += y_train_Q1_3_i

y_bar_train /= n_train_Q1_3
print('y_bar_train',y_bar_train)

#Next we shall compute sigma_yy, which is the variance of y_train_Q1_3
sigma_yy_train_Q1_3 = 0
for i in range(n_train_Q1_3): #access each row from the training data set 
  y_i = float(weight_height_data_Q1_3.iat[i,4]) #access element at weight_g column
  sigma_yy_train_Q1_3 += (y_i-y_bar_train)**2

print('sigma_yy_train_Q1_3:', sigma_yy_train_Q1_3)

#now we can compute sum of squared residuals 
sum_sq_residuals_train = 0
for i in range(n_train_Q1_3): #access each row from the training data set 
  x_i = X_train_Q1_3[i,:] #access i-th row of X_train_Q1_3
  y_i = y_train_Q1_3[i] #access i-th row of y_train_Q1_3

  y_pred_i = np.dot(x_i,beta_train_Q1_3) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals_train += (e_i)**2

print('sum of squared residuals:', sum_sq_residuals_train)
print('Root Mean Squared Error (RMSE):', np.sqrt(sum_sq_residuals_train/n_train_Q1_3))

#Then we will compute the R^2 quantity
R_sq_train = 1-sum_sq_residuals_train/sigma_yy_train_Q1_3
print('R^2 score:',R_sq_train)
# Out:
# y_bar_train 404.4782258064517
# sigma_yy_train_Q1_3: 15451937.951209672
# sum of squared residuals: [2135829.66193178]
# Root Mean Squared Error (RMSE): [131.24188644]
# R^2 score: [0.86177594]

# %% [markdown]
# ${\text{Finding $\beta$ using sklearn library}}$

# %%
from sklearn.linear_model import LinearRegression
# creating an object of LinearRegression class
LR = LinearRegression()
# fitting the training data
LR.fit(X_train_Q1_3,y_train_Q1_3)
#print the coefficients and the intercept
print('intercept: ', LR.intercept_)
print('coefficients:')
print(LR.coef_)

print('Recall the coefficients and intercept from our formula:')
print(beta_train_Q1_3)
# Out:
# intercept:  [-726.86845722]
# coefficients:
# [[28.02625976 17.87051592  0.        ]]
# Recall the coefficients and intercept from our formula:
# [[  28.02625976]
#  [  17.87051592]
#  [-726.86845722]]

# %% [markdown]
# $\large{\text{Compute performance on train data}}$

# %%
y_train_Q1_3_prediction = LR.predict(X_train_Q1_3)
y_train_Q1_3_prediction
# Out:
# array([[ 353.38424883],
#        [ 394.1639669 ],
#        [ 414.59301162],
#        [ 449.68910639],
#        [ 495.86916492],
#        [ 513.45639798],
#        [ 493.51554762],
#        [ 532.5082141 ],
#        [ 539.65642047],
#        [ 525.36000773],
#        [ 507.73358899],
#        [ 564.10857704],
#        [ 583.76614455],
#        [ 593.15041118],
#        [ 593.39450836],
#        [ 592.62303115],
#        [ 622.23143101],
#        [ 616.58699337],
#        [ 623.45191688],
#        [ 680.84247932],
#        [ 654.80818265],
#        [ 683.88920247],
#        [ 679.05542773],
#        [ 705.29463589],
#        [ 744.0432052 ],
#        [ 764.63797574],
#        [ 761.83534976],
#        [ 808.991797  ],
#        [ 822.23344967],
#        [ 341.96883343],
#        [ 353.42343451],
#        [ 407.97218529],
#        [ 679.62199344],
#        [ 760.33158103],
#        [ -22.65582628],
#        [  90.46478714],
#        [ 150.86288705],
#        [ 183.0298157 ],
# ...

# %%
# importing R2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# computing R2 score and sum of square residuals
score=r2_score(y_train_Q1_3,y_train_Q1_3_prediction)
print('From scikit learn:')
print('R2 score is:',score)
mse=mean_squared_error(y_train_Q1_3,y_train_Q1_3_prediction)
print('sum of squared residuals:',n_train_Q1_3*mse)
print('RMSE:',np.sqrt(mse))
print('*****************')

print('Recall the R2 score, sum of squared resuiduals and rmse from our formula: ')
print('R2:',R_sq_train)
print('sum of squared residuals:',sum_sq_residuals_train)
print('RMSE:',np.sqrt(sum_sq_residuals_train/n_train_Q1_3))
# Out:
# From scikit learn:
# R2 score is: 0.8617759358938809
# sum of squared residuals: 2135829.6619317806
# RMSE: 131.2418864445127
# *****************
# Recall the R2 score, sum of squared resuiduals and rmse from our formula:
# R2: [0.86177594]
# sum of squared residuals: [2135829.66193178]
# RMSE: [131.24188644]

# %% [markdown]
# ${\text{Prediction on weigth in test data with reduced variable}}$

# %%
weight_height_data_test_Q1_3 = pd.read_excel('https://github.com/arvind-maurya/MachineLearning/blob/master/Assignment/Q1/Q1_test.xlsx?raw=true', index_col=False, header=0)
weight_height_data_test_Q1_3
# Out:
#     Species  Length_cm  Height_pct  Width_pct  Weight_g
# 0         1       34.7        39.2       14.2       NaN
# 1         1       39.5        38.3       14.1       NaN
# 2         1       46.5        37.9       13.7       NaN
# 3         1       41.5        39.8       14.1       NaN
# 4         1       35.1        39.9       13.8       NaN
# 5         2       34.0        31.6       19.3       NaN
# 6         3       24.3        27.3       14.6       NaN
# 7         3       29.2        30.4       15.4       NaN
# 8         3       27.2        27.7       14.1       NaN
# 9         3       21.2        26.3       13.7       NaN
# 10        4       23.2        40.5       14.7       NaN
# 11        4       19.8        37.4       13.5       NaN
# 12        5       12.6        15.7       10.2       NaN
# 13        5       13.1        16.9        9.8       NaN
# 14        5       13.1        16.9        8.9       NaN
# 15        6       64.0        15.0        9.6       NaN
# ...

# %%
#extract the predictor variable columns 
cols = [1,3]
# print (airline_costs_data.columns[cols])
X_test_data_Q1_3 = weight_height_data_test_Q1_3[weight_height_data_test_Q1_3.columns[cols]]

X_test_data_Q1_3
# Out:
#     Length_cm  Width_pct
# 0        34.7       14.2
# 1        39.5       14.1
# 2        46.5       13.7
# 3        41.5       14.1
# 4        35.1       13.8
# 5        34.0       19.3
# 6        24.3       14.6
# 7        29.2       15.4
# 8        27.2       14.1
# 9        21.2       13.7
# 10       23.2       14.7
# 11       19.8       13.5
# 12       12.6       10.2
# 13       13.1        9.8
# 14       13.1        8.9
# 15       64.0        9.6
# 16       45.5        9.5
# 17       45.8       11.2
# 18       42.4       17.6
# 19       31.6       15.1
# 20       19.4       16.1
# 21       22.5       16.3
# 22       22.8       15.5
# 23       25.0       14.9
# 24       24.2       15.0
# 25       24.5       14.8
# 26       29.4       14.3
# 27       46.0       17.7
# 28       30.1       15.4
# 29       23.5       14.5
# 30       42.3       16.8
# 31       42.5       17.0
# 32       16.0       15.2

# %%
#convert predictor variable columns into a numpy array

X_test_array_Q1_3 = weight_height_data_test_Q1_3[weight_height_data_test_Q1_3.columns[cols]].to_numpy()
X_test_array_Q1_3
# Out:
# array([[34.7, 14.2],
#        [39.5, 14.1],
#        [46.5, 13.7],
#        [41.5, 14.1],
#        [35.1, 13.8],
#        [34. , 19.3],
#        [24.3, 14.6],
#        [29.2, 15.4],
#        [27.2, 14.1],
#        [21.2, 13.7],
#        [23.2, 14.7],
#        [19.8, 13.5],
#        [12.6, 10.2],
#        [13.1,  9.8],
#        [13.1,  8.9],
#        [64. ,  9.6],
#        [45.5,  9.5],
#        [45.8, 11.2],
#        [42.4, 17.6],
#        [31.6, 15.1],
#        [19.4, 16.1],
#        [22.5, 16.3],
#        [22.8, 15.5],
#        [25. , 14.9],
#        [24.2, 15. ],
#        [24.5, 14.8],
#        [29.4, 14.3],
#        [46. , 17.7],
#        [30.1, 15.4],
#        [23.5, 14.5],
#        [42.3, 16.8],
#        [42.5, 17. ],
#        [16. , 15.2]])

# %%
#add a column of ones to X_train_Q1_3_array
X_test_Q1_3 = np.hstack((X_test_array_Q1_3, np.ones((X_test_array_Q1_3.shape[0], 1), dtype=X_test_array_Q1_3.dtype)))

X_test_Q1_3
# Out:
# array([[34.7, 14.2,  1. ],
#        [39.5, 14.1,  1. ],
#        [46.5, 13.7,  1. ],
#        [41.5, 14.1,  1. ],
#        [35.1, 13.8,  1. ],
#        [34. , 19.3,  1. ],
#        [24.3, 14.6,  1. ],
#        [29.2, 15.4,  1. ],
#        [27.2, 14.1,  1. ],
#        [21.2, 13.7,  1. ],
#        [23.2, 14.7,  1. ],
#        [19.8, 13.5,  1. ],
#        [12.6, 10.2,  1. ],
#        [13.1,  9.8,  1. ],
#        [13.1,  8.9,  1. ],
#        [64. ,  9.6,  1. ],
#        [45.5,  9.5,  1. ],
#        [45.8, 11.2,  1. ],
#        [42.4, 17.6,  1. ],
#        [31.6, 15.1,  1. ],
#        [19.4, 16.1,  1. ],
#        [22.5, 16.3,  1. ],
#        [22.8, 15.5,  1. ],
#        [25. , 14.9,  1. ],
#        [24.2, 15. ,  1. ],
#        [24.5, 14.8,  1. ],
#        [29.4, 14.3,  1. ],
#        [46. , 17.7,  1. ],
#        [30.1, 15.4,  1. ],
#        [23.5, 14.5,  1. ],
#        [42.3, 16.8,  1. ],
#        [42.5, 17. ,  1. ],
#        [16. , 15.2,  1. ]])

# %% [markdown]
# ${\text{Compute predictions on test data:}}$

# %%
## Predict based on scikit learn

y_test_prediction_Q1_3 =  LR.predict(X_test_Q1_3)

y_test_prediction_Q1_3
# Out:
# array([[ 499.40408242],
#        [ 632.14307767],
#        [ 821.1786896 ],
#        [ 688.19559718],
#        [ 503.46637996],
#        [ 570.92533178],
#        [ 215.07918731],
#        [ 366.70427286],
#        [ 287.42008265],
#        [ 112.11431774],
#        [ 186.03735317],
#        [  69.30345089],
#        [-191.4583219 ],
#        [-184.59339839],
#        [-200.67686271],
#        [1238.36912009],
#        [ 718.09626298],
#        [ 756.88401797],
#        [ 775.96603668],
#        [ 428.6061415 ],
#        [ 104.55628838],
#        [ 195.01179681],
#        [ 189.123262  ],
#        [ 240.05872392],
#        [ 219.4247677 ],
#        [ 224.25854245],
#        [ 352.6519573 ],
#        [ 878.6476234 ],
#        [ 391.92790664],
#        [ 190.87112791],
#        [ 758.86699797],
#        [ 768.04635311],
#        [  -6.81645912]])

# %%
## we first compute size of test data
n_test_Q1_3 = len(weight_height_data_test_Q1_3.index) #number of data points in the test data
# print('number of data points in the test data:',n_test)

e_i_residuals_list_test = [] ## stores residuals on test data
for i in range(n_test_Q1_3): 
  x_i = X_test_Q1_3[i,:] #access i-th row of X_test

  y_pred_i_Q1_3 = np.dot(x_i,beta_train_Q1_3) # compute the prediction obtained using the regression coefficients 
  #e_i_test = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i
  
  print(y_pred_i_Q1_3)
# Out:
# [499.40408242]
# [632.14307767]
# [821.1786896]
# [688.19559718]
# [503.46637996]
# [570.92533178]
# [215.07918731]
# [366.70427286]
# [287.42008265]
# [112.11431774]
# [186.03735317]
# [69.30345089]
# [-191.4583219]
# [-184.59339839]
# [-200.67686271]
# [1238.36912009]
# [718.09626298]
# [756.88401797]
# [775.96603668]
# [428.6061415]
# [104.55628838]
# [195.01179681]
# [189.123262]
# [240.05872392]
# [219.4247677]
# [224.25854245]
# [352.6519573]
# [878.6476234]
# [391.92790664]
# [190.87112791]
# [758.86699797]
# [768.04635311]
# [-6.81645912]

# %%
weight_height_data_test_Q1_3.insert(5,'weight_predict',y_test_prediction_Q1_3)
weight_height_data_test_Q1_3
# Out:
#     Species  Length_cm  Height_pct  Width_pct  Weight_g  weight_predict
# 0         1       34.7        39.2       14.2       NaN      499.404082
# 1         1       39.5        38.3       14.1       NaN      632.143078
# 2         1       46.5        37.9       13.7       NaN      821.178690
# 3         1       41.5        39.8       14.1       NaN      688.195597
# 4         1       35.1        39.9       13.8       NaN      503.466380
# 5         2       34.0        31.6       19.3       NaN      570.925332
# 6         3       24.3        27.3       14.6       NaN      215.079187
# 7         3       29.2        30.4       15.4       NaN      366.704273
# 8         3       27.2        27.7       14.1       NaN      287.420083
# 9         3       21.2        26.3       13.7       NaN      112.114318
# 10        4       23.2        40.5       14.7       NaN      186.037353
# 11        4       19.8        37.4       13.5       NaN       69.303451
# ...

# %%
#We shall now compute R^2 for training weight height data

#first we shall compute y_bar 
y_bar_test = 0
for i in range(n_test_Q1_3): #access each row from the test data set 
  y_test_i = float(weight_height_data_test_Q1_3.iat[i,5]) #access element at weight_g column
  # y_test_i = y_test_prediction[i]
  y_bar_test += y_test_i

y_bar_test /= n_test_Q1_3
print('y_bar_test',y_bar_test)

#Next we shall compute sigma_yy, which is the variance of y_test
sigma_yy_test = 0
for i in range(n_test_Q1_3): #access each row from the training data set 
  y_i = float(weight_height_data_test_Q1_3.iat[i,5]) #access element at weight_g column
  # y_i = y_pred_i
  sigma_yy_test += (y_i-y_bar_test)**2

print('sigma_yy_test:', sigma_yy_test)

#now we can compute sum of squared residuals 
sum_sq_residuals_test = 0
for i in range(n_test_Q1_3): #access each row from the training data set 
  x_i = X_test_Q1_3[i,:] #access i-th row of X_test
  y_i = y_test_prediction_Q1_3[i] #access i-th row of y_test

  y_pred_i_Q1_3 = np.dot(x_i,beta_train_Q1_3) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_test_prediction_Q1_3[i] #compute the difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals_test += (e_i)**2

print('sum of squared residuals:', sum_sq_residuals_test)
rmse = np.sqrt(sum_sq_residuals_test/n_test)
print('Root Mean Squarred Error for test (RMSE):', rmse)

#Then we will compute the R^2 quantity
R_sq_test = 1 - sum_sq_residuals_test/sigma_yy_test
print('R^2 score for test:',R_sq_test)
# Out:
# y_bar_test 387.8725366047803
# sigma_yy_test: 3738990.587544996
# sum of squared residuals: [0.]
# Root Mean Squarred Error for test (RMSE): [0.]
# R^2 score for test: [1.]

# %% [markdown]
# ## **=====================================================================**

# %% [markdown]
# ## (b) Choose $\lambda \in \{10^{-3},10^{-2},0.1, 1, 10, 100, 1000\}$ and for every possible value of λ do the following:

# %% [markdown]
# **Linear Regression with Regularizers**

# %% [markdown]
# ### i. [C] Solve the OLSR model and find the optimal value of β for each value of λ

# %%
X_train_Q1_b = X_train.copy()
X_train_Q1_b
# Out:
# array([[ 1. , 30. , 38.4, 13.4,  1. ],
#        [ 1. , 31.2, 40. , 13.8,  1. ],
#        [ 1. , 31.1, 39.8, 15.1,  1. ],
#        [ 1. , 33.5, 38. , 13.3,  1. ],
#        [ 1. , 34. , 36.6, 15.1,  1. ],
#        [ 1. , 34.5, 41.1, 15.3,  1. ],
#        [ 1. , 35. , 36.2, 13.4,  1. ],
#        [ 1. , 36.2, 39.3, 13.7,  1. ],
#        [ 1. , 36.2, 39.4, 14.1,  1. ],
#        [ 1. , 36.2, 39.7, 13.3,  1. ],
#        [ 1. , 36.4, 37.8, 12. ,  1. ],
#        [ 1. , 37.2, 40.2, 13.9,  1. ],
#        [ 1. , 37.2, 41.5, 15. ,  1. ],
#        [ 1. , 38.3, 38.8, 13.8,  1. ],
#        [ 1. , 38.5, 38.8, 13.5,  1. ],
#        [ 1. , 38.6, 40.5, 13.3,  1. ],
#        [ 1. , 38.7, 37.4, 14.8,  1. ],
#        [ 1. , 39.2, 40.8, 13.7,  1. ],
#        [ 1. , 39.7, 39.1, 13.3,  1. ],
#        [ 1. , 40.6, 38.1, 15.1,  1. ],
#        [ 1. , 40.5, 40.1, 13.8,  1. ],
#        [ 1. , 40.9, 40. , 14.8,  1. ],
#        [ 1. , 40.6, 40.3, 15. ,  1. ],
#        [ 1. , 41.6, 40.6, 14.9,  1. ],
# ...

# %%
y_train_Q1_b = y_train.copy()
y_train_Q1_b
# Out:
# array([[ 242. ],
#        [ 290. ],
#        [ 340. ],
#        [ 363. ],
#        [ 430. ],
#        [ 500. ],
#        [ 390. ],
#        [ 500. ],
#        [ 475. ],
#        [ 500. ],
#        [ 500. ],
#        [ 600. ],
#        [ 600. ],
#        [ 700. ],
#        [ 700. ],
#        [ 610. ],
#        [ 650. ],
#        [ 685. ],
#        [ 620. ],
#        [ 680. ],
#        [ 700. ],
#        [ 725. ],
#        [ 720. ],
#        [ 850. ],
#        [1000. ],
#        [ 920. ],
#        [ 955. ],
#        [ 925. ],
#        [ 975. ],
#        [ 270. ],
#        [ 270. ],
#        [ 306. ],
#        [ 800. ],
#        [1000. ],
#        [  40. ],
#        [  69. ],
#        [  87. ],
#        [ 120. ],
#        [ 110. ],
#        [ 120. ],
#        [ 150. ],
#        [ 160. ],
#        [ 140. ],
#        [ 160. ],
#        [ 161. ],
#        [ 200. ],
#        [ 180. ],
#        [ 272. ],
#        [ 390. ],
#        [  55. ],
#        [  60. ],
#        [ 120. ],
# ...

# %%
#Now we are ready for finding beta
#print('X shape:',X.shape,'y shape:',y.shape)

XTX = np.matmul(np.transpose(X_train_Q1_b),X_train_Q1_b)
print('XTX shape:',XTX.shape)

Xy = np.matmul(np.transpose(X_train_Q1_b),y_train_Q1_b)
#print('Xy shape:',Xy.shape)

#solving a system of linear equations Ax=b, can be done using np.linalg.solve(A,b)

beta_Q1_b =np.linalg.solve(XTX,Xy)
#beta = np.matmul(np.linalg.inv(XTX),Xy)

print('beta',beta_Q1_b)
# Out:
# XTX shape: (5, 5)
# beta [[   2.4173551 ]
#  [  27.8581628 ]
#  [   2.67475542]
#  [  13.06363395]
#  [-740.77633006]]

# %%
print(np.linalg.matrix_rank(XTX))
XTX_inv = np.linalg.inv(XTX)

#print(np.matmul(XTX,XTX_inv))
is_identity = np.all(np.matmul(XTX,XTX_inv)==np.identity(XTX.shape[0]))
print(is_identity)
# Out:
# 5
# False

# %%
import scipy.linalg
#Now we are ready for finding beta
#print('X shape:',X.shape,'y shape:',y.shape)

XTX = np.matmul(np.transpose(X_train_Q1_b),X_train_Q1_b)
#print('XTX shape:',XTX.shape)

Xy = np.matmul(np.transpose(X_train_Q1_b),y_train_Q1_b)
#print('Xy shape:',Xy.shape)

beta_Q1_b_scipy =scipy.linalg.solve(XTX,Xy)
#beta = np.matmul(scipy.linalg.inv(XTX),Xy)

print('beta', beta_Q1_b_scipy)
# Out:
# beta [[   2.4173551 ]
#  [  27.8581628 ]
#  [   2.67475542]
#  [  13.06363395]
#  [-740.77633006]]

# %%
#condition number of XTX
print('Condition number :' ,np.linalg.cond(XTX))
# Out:
# Condition number : 120463.3214158098

# %% [markdown]
# Since Condition number (120463.3214158098) is not high, we can see that matrix is not ill-conditioned.
#
# Lets see if we can improve the beta value using $(l_2)$ regularizer

# %%
lambdas = np.array([1e-3,1e-2,1e-1,1,10,100,1000])
I = np.identity(XTX.shape[0])

for lambda_ in lambdas:
  print('lambda:',lambda_,'cond(XTX+lambda I):', np.linalg.cond(XTX+lambda_*I))
# Out:
# lambda: 0.001 cond(XTX+lambda I): 120408.27778440723
# lambda: 0.01 cond(XTX+lambda I): 119915.139460895
# lambda: 0.1 cond(XTX+lambda I): 115197.18115351009
# lambda: 1.0 cond(XTX+lambda I): 82671.07714386939
# lambda: 10.0 cond(XTX+lambda I): 21622.344192326935
# lambda: 100.0 cond(XTX+lambda I): 2579.6901721911277
# lambda: 1000.0 cond(XTX+lambda I): 263.93470428972427

# %%
import scipy.linalg
#Now we are ready for finding beta
#print('X shape:',X.shape,'y shape:',y.shape)

betas = [] 
for lambda_ in lambdas:
  beta =scipy.linalg.solve(XTX+lambda_*I,Xy)
  print('lambda:',lambda_)
  print('beta:\n',beta)
  print('*************************')
  betas.append(beta)
# Out:
# lambda: 0.001
# beta:
#  [[   2.40478713]
#  [  27.85678005]
#  [   2.67147441]
#  [  13.05370527]
#  [-740.43836035]]
# *************************
# lambda: 0.01
# beta:
#  [[   2.29219272]
#  [  27.84439174]
#  [   2.64208025]
#  [  12.96475214]
#  [-737.41047467]]
# *************************
# lambda: 0.1
# beta:
#  [[   1.21522313]
#  [  27.72585857]
#  [   2.36091552]
#  [  12.11355834]
#  [-708.44204906]]
# *************************
# lambda: 1.0
# beta:
#  [[-6.19203216e+00]
#  [ 2.69078413e+01]
#  [ 4.26483569e-01]
#  [ 6.23390156e+00]
#  [-5.08730302e+02]]
# *************************
# lambda: 10.0
# beta:
#  [[ -19.65894758]
#  [  25.35066218]
#  [  -3.10719032]
#  [  -5.08182166]
#  [-133.87937211]]
# *************************
# lambda: 100.0
# beta:
#  [[-20.30951741]
#  [ 24.61182352]
#  [ -3.51646317]
#  [-10.51468709]
#  [-16.87109099]]
# *************************
# lambda: 1000.0
# beta:
#  [[-11.27933917]
#  [ 22.49551675]
#  [ -3.03448488]
#  [-10.29326243]
# ...

# %% [markdown]
# ### ii. [C, R] Let the optimal β corresponding to a particular value of λ be called $ \beta_0^* $. Report thevalue of $ \beta_0^* $and the RMSE and $R^2$ values for train data set.

# %%
#Residual Plot
beta_idx = 0
for lambda_ in lambdas: 
  beta = betas[beta_idx]
  beta_idx += 1
  xlabel = 'TOC lambda='+str(lambda_)
  e_i_residuals_list = [] 

  for i in range(n_train): 
    x_i = X_train_Q1_b[i,:] #access i-th row of X
    y_i = y_train_Q1_b[i] #access i-th row of y

    y_pred_i = np.dot(x_i,beta) #compute the prediction obtained using the regression coefficients 
    e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

    e_i_residuals_list.append(e_i) #append the value of e_i to the list 

  #plot the residuals e_i against the actual observations y_i
  plt.scatter(weight_height_data['Weight_g'], e_i_residuals_list,color='r')
  plt.title("Residual plot")
  plt.xlabel(xlabel)
  plt.ylabel("Residuals")
  plt.grid()
  plt.show()

# %% [markdown]
# Let us compute $R^2$.

# %%
#Let us compute R^2
#We shall now compute R^2 for airline costs data

#first we shall compute y_bar 
y_bar = 0
for i in range(n_train): #access each row from the data set 
  y_i = float(weight_height_data.iat[i,4]) #access element at weight_g column
  y_bar += y_i

y_bar /= n_train
print('y_bar',y_bar)

#Next we shall compute sigma_yy, which is the variance of y 
sigma_yy = 0
for i in range(n_train): #access each row from the data set 
  y_i = float(weight_height_data.iat[i,4]) #access element at weight column
  sigma_yy += (y_i-y_bar)**2

print('sigma_yy:', sigma_yy)
print('===============================')

#now we can compute sum of squared residuals 
beta_idx = 0
for lambda_ in lambdas:
  beta = betas[beta_idx]
  beta_idx+=1
  sum_sq_residuals = 0
  for i in range(n_train): #access each row from the data set 
    x_i = X_train_Q1_b[i,:] #access i-th row of X
    y_i = y_train_Q1_b[i] #access i-th row of y

    y_pred_i = np.dot(x_i,beta) #compute the prediction obtained using the regression coefficients 
    e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

    sum_sq_residuals += (e_i)**2

  print('lambda:',lambda_)
  print('beta:\n',beta)
  print('sum of squared residuals:', sum_sq_residuals)

  #Then we will compute the R^2 quantity
  R_sq = 1-sum_sq_residuals/sigma_yy
  print('R^2:',R_sq)
  print('*********************')
# Out:
# y_bar 404.4782258064517
# sigma_yy: 15451937.951209672
# ...
# lambda: 0.001
# beta:
#  [[   2.40478713]
#  [  27.85678005]
#  [   2.67147441]
#  [  13.05370527]
#  [-740.43836035]]
# sum of squared residuals: [2104316.56118645]
# R^2: [0.86381536]
# *********************
# lambda: 0.01
# beta:
#  [[   2.29219272]
#  [  27.84439174]
#  [   2.64208025]
#  [  12.96475214]
#  [-737.41047467]]
# sum of squared residuals: [2104341.15129039]
# R^2: [0.86381377]
# *********************
# lambda: 0.1
# beta:
#  [[   1.21522313]
#  [  27.72585857]
#  [   2.36091552]
#  [  12.11355834]
#  [-708.44204906]]
# sum of squared residuals: [2106608.74504809]
# R^2: [0.86366702]
# *********************
# lambda: 1.0
# beta:
#  [[-6.19203216e+00]
#  [ 2.69078413e+01]
#  [ 4.26483569e-01]
#  [ 6.23390156e+00]
#  [-5.08730302e+02]]
# sum of squared residuals: [2222380.9528277]
# R^2: [0.85617461]
# *********************
# lambda: 10.0
# beta:
#  [[ -19.65894758]
#  [  25.35066218]
#  [  -3.10719032]
# ...

# %% [markdown]
# **We observed that lambda = 0.001 is optimal  β**

# %% [markdown]
# ### iii. [C, R] Using $ \beta_0^* $, predict the Weight g value for the test data set in Q1 test.xlsx file and report the predictions.

# %%
## extracting beta value associated with lambdaa = 0.001
beta_train = betas[0] ## index 0 corresponds to lambda = 0.001
print ('best beta:')
print (beta_train)
# Out:
# best beta:
# [[   2.40478713]
#  [  27.85678005]
#  [   2.67147441]
#  [  13.05370527]
#  [-740.43836035]]

# %%
beta_idx = 0
for lambda_i in lambdas: 
  beta = betas[beta_idx]
  beta_idx += 1
  y_test_pred = np.matmul(X_test, beta)

  print('For lambda:',lambda_i)
  print('Beta is: \n', beta)
  print('Predicted y value is:\n', y_test_pred)
  print('*********************\n')
# Out:
# For lambda: 0.001
# Beta is:
#  [[   2.40478713]
#  [  27.85678005]
#  [   2.67147441]
#  [  13.05370527]
#  [-740.43836035]]
# Predicted y value is:
#  [[ 518.68110615]
#  [ 648.68395288]
#  [ 837.39134134]
#  [ 708.40472459]
#  [ 526.47236814]
#  [ 547.85683864]
#  [ 207.21110456]
#  [ 362.43386168]
#  [ 282.53750383]
#  [ 106.43527726]
#  [ 215.54226635]
#  [  96.8831972 ]
#  [-202.32905408]
#  [-190.41637688]
#  [-202.16471162]
#  [1222.21197227]
#  [ 708.22764526]
#  [ 741.44745265]
#  [ 765.27488915]
#  [ 418.16288197]
#  [  98.57685156]
#  [ 183.53639915]
#  [ 188.66344985]
#  [ 234.368867  ]
#  [ 212.05307629]
#  [ 208.9835037 ]
#  [ 353.11368766]
#  [ 862.05601392]
#  [ 383.23244533]
#  [ 189.76654179]
#  [ 749.37477252]
#  [ 755.95398494]
#  [ -15.63181114]]
# *********************
#
# For lambda: 0.01
# Beta is:
#  [[   2.29219272]
#  [  27.84439174]
#  [   2.64208025]
#  [  12.96475214]
#  [-737.41047467]]
# Predicted y value is:
#  [[ 518.75113792]
#  [ 648.72987085]
# ...

# %% [markdown]
# ### (c) [R] Justify with proper reasons which value of λ can be considered to be the best value for the OLSR model.

# %% [markdown]
# Looking at the above , we found that for λ = 0.001 we are getting best β and subsequently getting best value for prediction of Y response variable
